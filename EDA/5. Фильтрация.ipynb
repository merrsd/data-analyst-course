# %% [markdown]
# # Фильтрация
# Фильтрация — выделение части датасета по некоторому условию

# %% [markdown]
# ### Подгрузка датасета

# %%
# !gdown --id 1LjVzFpLoB0vfB1wSuc7PxZ0VyiJFNOVS
import pandas as pd
dataset = pd.read_csv('housing_market_dataset.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1LjVzFpLoB0vfB1wSuc7PxZ0VyiJFNOVS
# To: /content/housing_market_dataset.csv
# 100% 29.4M/29.4M [00:00<00:00, 49.0MB/s]

# %% [markdown]
# ### Кейс 1. Мы ищем квартиру в которую можно проинвестировать на этапе котлована

# %% [markdown]
# > фильтр = датасет[название_фильтруемой_колонки] == значение
#
# > новый_датасет = датасет[фильтр]

# %%
filter = dataset['Этап строительства']=='Котлован'
filtered_dataset = dataset[filter]

filtered_dataset.head()
# Out:
#                                                      url  \
# 1846   https://move.ru/objects/moskva_mishina_ulica_d...
# 3321   https://move.ru/objects/moskva_letchika_gricev...
# 8116   https://move.ru/objects/moskva_zelenodolskaya_...
# 11452  https://move.ru/objects/prodaetsya_2-k_kvartir...
# 11453  https://move.ru/objects/prodaetsya_1-k_kvartir...
#
#                                                Заголовок  \
# 1846   Продам 1-комнатную квартиру, 35 м², Москва, ул...
# 3321   Продаю 2-комнатную квартиру, 51 м², Москва, ул...
# 8116   Продаем 1-комнатную квартиру, 48 м², Москва, у...
# 11452  Продаю 2-комнатную квартиру, 62 м², Москва, Из...
# 11453  Продам 1-комнатную квартиру, 43 м², Москва, Из...
#
#                                              Новостройка Этап строительства  \
# 1846   ЖК «Лидер на Масловке» («Дом на Мишина»), м. Д...           Котлован
# 3321          Жилой комплекс «Солнцево парк», д. Пыхтино           Котлован
# ...

# %% [markdown]
# ### Кейс 2. Мы рассматриваем только квартиры в новостройках

# %% [markdown]
# > фильтр = датасет[название_фильтруемой_колонки] > значение
#
# > новый_датасет = датасет[фильтр]

# %%
filter = dataset['Год постройки']>2010
filtered_dataset = dataset[filter]

filtered_dataset.head()
# Out:
#                                                  url  \
# 1  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 2  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 3  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 4  https://move.ru/objects/prodaetsya_3-komn_kvar...
# 5  https://move.ru/objects/prodaetsya_3-komn_kvar...
#
#                                            Заголовок  \
# 1  Продам 2-комнатную квартиру, 83.2 м², Москва, ...
# 2  Продаю 2-комнатную квартиру, 89.6 м², Москва, ...
# 3  Продам 2-комнатную квартиру, 55.8 м², Москва, ...
# 4  Продаю 3-комнатную квартиру, 128 м², Москва, Д...
# 5  Продам 3-комнатную квартиру, 126.7 м², Москва,...
#
#                                          Новостройка Этап строительства  \
# 1         ЖК City Park («Сити Парк»), м. Выставочная            Отделка
# 2  ЖК Silver (ЖК «Резиденции кинематографистов»),...            Отделка
# 3     Новостройка «Некрасовка-Парк», 5 кв-л, корп. 1               Сдан
# ...

# %% [markdown]
# ### Кейс 3. Мы рассматриваем только квартиры в определенных районах.

# %% [markdown]
# > список_значений = [значние1, значение2]
#
# > фильтр = датасет[название_фильтруемой_колонки].isin(список_значений)
#
# > новый_датасет = датасет[фильтр]

# %%
districts = ['Строгино', 'Щукино']

filter = dataset['Район'].isin(districts)

filtered_dataset = dataset[filter]

filtered_dataset.head()
# Out:
#                                                    url  \
# 142  https://move.ru/objects/volokolamskoe_shosse_d...
# 232  https://move.ru/objects/moskva_ulica_marshala_...
# 247  https://move.ru/objects/moskva_ulica_raspletin...
# 248  https://move.ru/objects/moskva_ulica_raspletin...
# 335  https://move.ru/objects/moskva_ulica_tallinska...
#
#                                              Заголовок Новостройка  \
# 142  Продам 4-комнатную квартиру, 150 м², Москва, В...         NaN
# 232  Продается 4-комнатная квартира, 100 м², Москва...         NaN
# 247  Продам 4-комнатную квартиру, 190 м², Москва, у...         NaN
# 248  Продажа 5-комнатной квартиры, 190 м², Москва, ...         NaN
# 335  Продаем 3-комнатную квартиру, 80 м², Москва, у...         NaN
#
#     Этап строительства  Год постройки Класс жилья               МЦК  \
# 142                NaN            NaN         NaN     МЦК Стрешнево
# 232                NaN         1958.0         NaN  МЦК Панфиловская
# ...

# %% [markdown]
# ### Кейс 4. Мы рассматриваем только квартиры в определенных районах, при этом нас интересуют только новостройки

# %% [markdown]
# > сложный_фильтр = (фильтр1) & (фильтр2)
#
# > новый_датасет = датасет[сложный_фильтр]

# %%
filter = (dataset['Район'].isin(districts)) & (dataset['Год постройки']>2010)

filtered_dataset = dataset[filter]
filtered_dataset.head()
# Out:
#                                                    url  \
# 606  https://move.ru/objects/prodaetsya_3-komnatnay...
# 607  https://move.ru/objects/prodaetsya_3-komnatnay...
# 608  https://move.ru/objects/prodaetsya_5-komnatnay...
# 609  https://move.ru/objects/prodaetsya_5-komnatnay...
# 610  https://move.ru/objects/prodaetsya_2-komnatnay...
#
#                                              Заголовок  \
# 606  Продается 3-комнатная квартира, 100 м², Москва...
# 607  Продаю 3-комнатную квартиру, 125 м², Москва, А...
# 608  Продам 5-комнатную квартиру, 205 м², Москва, А...
# 609  Продаем 5-комнатную квартиру, 216 м², Москва, ...
# 610  Продажа 2-комнатной квартиры, 83 м², Москва, А...
#
#                        Новостройка Этап строительства  Год постройки  \
# 606  ЖК «Алые Паруса» м. Щукинская               Сдан         2016.0
# 607  ЖК «Алые Паруса» м. Щукинская               Сдан         2016.0
# 608  ЖК «Алые Паруса» м. Щукинская               Сдан         2016.0
# ...

# %% [markdown]
# Альтернативный вариант - применить нужные фильтры последовательно

# %%
filtered_dataset = dataset[dataset['Район'].isin(districts)]

double_filtered_dataset = filtered_dataset[filtered_dataset['Год постройки']>2010]

double_filtered_dataset.head()
# Out:
#                                                    url  \
# 606  https://move.ru/objects/prodaetsya_3-komnatnay...
# 607  https://move.ru/objects/prodaetsya_3-komnatnay...
# 608  https://move.ru/objects/prodaetsya_5-komnatnay...
# 609  https://move.ru/objects/prodaetsya_5-komnatnay...
# 610  https://move.ru/objects/prodaetsya_2-komnatnay...
#
#                                              Заголовок  \
# 606  Продается 3-комнатная квартира, 100 м², Москва...
# 607  Продаю 3-комнатную квартиру, 125 м², Москва, А...
# 608  Продам 5-комнатную квартиру, 205 м², Москва, А...
# 609  Продаем 5-комнатную квартиру, 216 м², Москва, ...
# 610  Продажа 2-комнатной квартиры, 83 м², Москва, А...
#
#                        Новостройка Этап строительства  Год постройки  \
# 606  ЖК «Алые Паруса» м. Щукинская               Сдан         2016.0
# 607  ЖК «Алые Паруса» м. Щукинская               Сдан         2016.0
# 608  ЖК «Алые Паруса» м. Щукинская               Сдан         2016.0
# ...

# %% [markdown]
# ### Кейс 5. Мы рассматриваем все квартиры, но определенные районы нам не подходят

# %% [markdown]
# > фильтр_все_кроме = ~(фильтр)
#
# > новый_датасет = датасет[фильтр_все_кроме]

# %%
filter = ~(dataset['Район'].isin(districts))

filtered_dataset = dataset[filter]
filtered_dataset.head()
# Out:
#                                                  url  \
# 0  https://move.ru/objects/moskva_ulica_baykalska...
# 1  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 2  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 3  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 4  https://move.ru/objects/prodaetsya_3-komn_kvar...
#
#                                            Заголовок  \
# 0  Продажа 1-комнатной квартиры, 31 м², Москва, у...
# 1  Продам 2-комнатную квартиру, 83.2 м², Москва, ...
# 2  Продаю 2-комнатную квартиру, 89.6 м², Москва, ...
# 3  Продам 2-комнатную квартиру, 55.8 м², Москва, ...
# 4  Продаю 3-комнатную квартиру, 128 м², Москва, Д...
#
#                                          Новостройка Этап строительства  \
# 0                                                NaN                NaN
# 1         ЖК City Park («Сити Парк»), м. Выставочная            Отделка
# 2  ЖК Silver (ЖК «Резиденции кинематографистов»),...            Отделка
# ...

# %% [markdown]
# ### Шаблоны фильтрации

# %%
# Шаблон фильтрации по одному значению в колонке
filtered_dataset = dataset[dataset['Этап строительства']=='Котлован']

# %%
# Шаблон фильтрации числовой колонки
filtered_dataset = dataset[dataset['Год постройки']>2010]

# %%
# Шаблон фильтрации по нескольким значениям в колонке
districts = ['Строгино', 'Щукино', 'Хорошёвский']
filtered_dataset = dataset[dataset['Район'].isin(districts)]

# %%
# Шаблон фильтрации по нескольким колонкам
districts = ['Строгино', 'Щукино', 'Хорошёвский']
filtered_dataset = dataset[(dataset['Район'].isin(districts)) & (dataset['Год постройки']>2010)]

# %%
# Шаблон фильтрации по всем значениям кроме заданных в фильтре
districts = ['Строгино', 'Щукино', 'Хорошёвский']
filtered_dataset = dataset[~(dataset['Район'].isin(districts))]

# %% [markdown]
# ## Тестирование

# %%
#Отфильтруйте все строительные объекты с ценой выше 10 млн. Сколько их в датасете?
dataset['Цена']
# Out:
# 0         5 250 000 ₽
# 1        22 297 600 ₽
# 2        15 660 826 ₽
# 3         5 945 490 ₽
# 4        27 170 560 ₽
#              ...
# 12996     4 196 491 ₽
# 12997     4 196 491 ₽
# 12998     5 733 626 ₽
# 12999     4 130 670 ₽
# 13000     4 147 989 ₽
# Name: Цена, Length: 13001, dtype: object

# %%
import re
def clear_price(price):
  return int(re.sub('\D', '', price))

# %%
dataset['Очищенная цена'] = dataset['Цена'].apply(clear_price)

# %%
(dataset[dataset['Очищенная цена'] > 10000000]).shape
# Out:
# (4362, 38)

# %%
#Отфильтруйте все строительные объекты на этапе строительства «Сдан». Сколько их в датасете?
type = ['Сдан']
sum(dataset['Этап строительства'].isin(type))
# Out:
# 1050

# %%
#Отфильтруйте все строительные объекты в районах Строгино и Щукино. Сколько их в датасете?
district = ['Строгино', 'Щукино']
sum(dataset['Район'].isin(district))
# Out:
# 99
